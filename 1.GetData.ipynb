# %% [markdown]
# Code based on: https://towardsdatascience.com/sports-reference-api-intro-dbce09e89e52
#
# Also see: https://towardsdatascience.com/beating-the-odds-8d26b1a83f1b

# %%
#!pip install sportsreference
import pandas as pd

# %% [markdown]
# ### Teams

# %%
from sportsreference.nfl.teams import Teams
teams2020 = Teams(year = '2020')
print(dir(teams2020))
# Out:
# ['__call__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_add_stats_data', '_retrieve_all_teams', '_teams', 'dataframes']

# %%
nfl_teams = teams2020.dataframes

# %%
nfl_teams.columns
# Out:
# Index(['abbreviation', 'defensive_simple_rating_system', 'first_downs',
#        'first_downs_from_penalties', 'fumbles', 'games_played',
#        'interceptions', 'losses', 'margin_of_victory', 'name',
#        'offensive_simple_rating_system', 'pass_attempts', 'pass_completions',
#        'pass_first_downs', 'pass_net_yards_per_attempt', 'pass_touchdowns',
#        'pass_yards', 'penalties', 'percent_drives_with_points',
#        'percent_drives_with_turnovers', 'plays', 'points_against',
#        'points_contributed_by_offense', 'points_difference', 'points_for',
#        'post_season_result', 'rank', 'rush_attempts', 'rush_first_downs',
#        'rush_touchdowns', 'rush_yards', 'rush_yards_per_attempt',
#        'simple_rating_system', 'strength_of_schedule', 'turnovers',
#        'win_percentage', 'wins', 'yards', 'yards_from_penalties',
#        'yards_per_play'],
#       dtype='object')

# %%
nfl_teams.head()
# Out:
#     abbreviation  defensive_simple_rating_system  first_downs  \
# GNB          GNB                             1.8          358
# BUF          BUF                             0.6          397
# TAM          TAM                             2.8          364
# OTI          OTI                            -3.1          381
# NOR          NOR                             4.5          367
#
#      first_downs_from_penalties  fumbles  games_played  interceptions  losses  \
# GNB                          28        6            16              5       3
# BUF                          38       11            16             11       3
# TAM                          44        5            16             12       5
# OTI                          36        5            16              7       5
# NOR                          21        9            16              8       4
#
#      margin_of_victory                  name  ...  rush_yards  \
# ...

# %% [markdown]
# ### Schedule

# %%
from sportsreference.nfl.schedule import Schedule
no2020 = Schedule('NOR', year = '2020')
no2020 = no2020.dataframe
no2020.head()
# Out:
#              boxscore_index          date   datetime  day  \
# 202009130nor   202009130nor  September 13 2020-09-13  Sun
# 202009210rai   202009210rai  September 21 2020-09-21  Mon
# 202009270nor   202009270nor  September 27 2020-09-27  Sun
# 202010040det   202010040det     October 4 2020-10-04  Sun
# 202010120nor   202010120nor    October 12 2020-10-12  Mon
#
#               extra_points_attempted  extra_points_made  \
# 202009130nor                       4                  4
# 202009210rai                       3                  3
# 202009270nor                       3                  3
# 202010040det                       5                  5
# 202010120nor                       3                  3
#
#               field_goals_attempted  field_goals_made  fourth_down_attempts  \
# 202009130nor                      2                 2                     1
# 202009210rai                      1                 1                     0
# ...

# %%
no2020.columns
# Out:
# Index(['boxscore_index', 'date', 'datetime', 'day', 'extra_points_attempted',
#        'extra_points_made', 'field_goals_attempted', 'field_goals_made',
#        'fourth_down_attempts', 'fourth_down_conversions', 'interceptions',
#        'location', 'opponent_abbr', 'opponent_name', 'overtime',
#        'pass_attempts', 'pass_completion_rate', 'pass_completions',
#        'pass_touchdowns', 'pass_yards', 'pass_yards_per_attempt',
#        'points_allowed', 'points_scored', 'punt_yards', 'punts',
#        'quarterback_rating', 'result', 'rush_attempts', 'rush_touchdowns',
#        'rush_yards', 'rush_yards_per_attempt', 'third_down_attempts',
#        'third_down_conversions', 'time_of_possession', 'times_sacked', 'type',
#        'week', 'yards_lost_from_sacks'],
#       dtype='object')

# %% [markdown]
# ### Boxscore

# %%
from sportsreference.nfl.boxscore import Boxscore
game_data = Boxscore('202009130nor')
gameplay_data = game_data.dataframe
gameplay_data.head()
# Out:
#              attendance  away_first_downs  away_fourth_down_attempts  \
# 202009130nor       None                23                          1
#
#               away_fourth_down_conversions  away_fumbles  away_fumbles_lost  \
# 202009130nor                             1             2                  1
#
#               away_interceptions  away_net_pass_yards  away_pass_attempts  \
# 202009130nor                   2                  224                  36
#
#               away_pass_completions  ...  home_turnovers  \
# 202009130nor                     23  ...               0
#
#               home_yards_from_penalties  home_yards_lost_from_sacks  \
# 202009130nor                        119                           9
#
#               losing_abbr           losing_name                  stadium  \
# 202009130nor          TAM  Tampa Bay Buccaneers  Mercedes-Benz Superdome
#
#                 time  winner  winning_abbr        winning_name
# ...

# %%
gameplay_data.columns
# Out:
# Index(['attendance', 'away_first_downs', 'away_fourth_down_attempts',
#        'away_fourth_down_conversions', 'away_fumbles', 'away_fumbles_lost',
#        'away_interceptions', 'away_net_pass_yards', 'away_pass_attempts',
#        'away_pass_completions', 'away_pass_touchdowns', 'away_pass_yards',
#        'away_penalties', 'away_points', 'away_rush_attempts',
#        'away_rush_touchdowns', 'away_rush_yards', 'away_third_down_attempts',
#        'away_third_down_conversions', 'away_time_of_possession',
#        'away_times_sacked', 'away_total_yards', 'away_turnovers',
#        'away_yards_from_penalties', 'away_yards_lost_from_sacks', 'date',
#        'duration', 'home_first_downs', 'home_fourth_down_attempts',
#        'home_fourth_down_conversions', 'home_fumbles', 'home_fumbles_lost',
#        'home_interceptions', 'home_net_pass_yards', 'home_pass_attempts',
#        'home_pass_completions', 'home_pass_touchdowns', 'home_pass_yards',
# ...

# %% [markdown]
# ### Player Gameplay

# %%
game_data.home_players[0].dataframe
# Out:
#           completed_passes  attempted_passes  passing_yards  \
# BreeDr00                18                30            160
#
#           passing_touchdowns  interceptions_thrown  times_sacked  \
# BreeDr00                   2                     0             1
#
#           yards_lost_from_sacks  longest_pass  quarterback_rating  \
# BreeDr00                      9            46                96.5
#
#           rush_attempts  ...  punt_return_touchdown  longest_punt_return  \
# BreeDr00              2  ...                   None                 None
#
#           extra_points_made  extra_points_attempted  field_goals_made  \
# BreeDr00               None                    None              None
#
#           field_goals_attempted  punts  total_punt_yards  yards_per_punt  \
# BreeDr00                   None   None              None            None
#
#           longest_punt
# BreeDr00          None
#
# [1 rows x 53 columns]

# %%
home_df = game_data.home_players[0].dataframe
for player in game_data.home_players[1:]:
    home_df = pd.concat([home_df, player.dataframe], axis = 0)
home_df['name'] = [x.name for x in game_data.home_players]
home_df.set_index('name', inplace = True)
home_df
# Out:
#                          completed_passes attempted_passes passing_yards  \
# name
# Drew Brees                             18               30           160
# Taysom Hill                             1                1            38
# Latavius Murray                         0                0             0
# Alvin Kamara                            0                0             0
# Deonte Harris                           0                0             0
# Jared Cook                              0                0             0
# Michael Thomas                          0                0             0
# Emmanuel Sanders                        0                0             0
# Tre'Quan Smith                          0                0             0
# Josh Hill                               0                0             0
# Ty Montgomery                           0                0             0
# Janoris Jenkins                      None             None          None
# ...

# %%
home_df.columns
# Out:
# Index(['completed_passes', 'attempted_passes', 'passing_yards',
#        'passing_touchdowns', 'interceptions_thrown', 'times_sacked',
#        'yards_lost_from_sacks', 'longest_pass', 'quarterback_rating',
#        'rush_attempts', 'rush_yards', 'rush_touchdowns', 'longest_rush',
#        'times_pass_target', 'receptions', 'receiving_yards',
#        'receiving_touchdowns', 'longest_reception', 'fumbles', 'fumbles_lost',
#        'interceptions', 'yards_returned_from_interception',
#        'interceptions_returned_for_touchdown', 'longest_interception_return',
#        'passes_defended', 'sacks', 'combined_tackles', 'solo_tackles',
#        'assists_on_tackles', 'tackles_for_loss', 'quarterback_hits',
#        'fumbles_recovered', 'yards_recovered_from_fumble',
#        'fumbles_recovered_for_touchdown', 'fumbles_forced', 'kickoff_returns',
#        'kickoff_return_yards', 'average_kickoff_return_yards',
#        'kickoff_return_touchdown', 'longest_kickoff_return', 'punt_returns',
# ...

# %% [markdown]
# ### Roster

# %%
from sportsreference.nfl.roster import Roster
nor2020 = Roster('NOR', year = '2020', slim=True)

# %%
nor2020.players
# Out:
# {'AlexKw00': 'Kwon Alexander',
#  'AnzaAl00': 'Alex Anzalone',
#  'ArmsTe00': 'Terron Armstead',
#  'BaunZa00': 'Zack Baun',
#  'BreeDr00': 'Drew Brees',
#  'BrowMa01': 'Malcom Brown',
#  'BurtMi00': 'Michael Burton',
#  'CallMa01': 'Marquez Callaway',
#  'CarrAu00': 'Austin Carr',
#  'ClapWi00': 'Will Clapp',
#  'CookJa02': 'Jared Cook',
#  'CrawKe02': 'Ken Crawley',
#  'DaveMa00': 'Marcus Davenport',
#  'DaviDe00': 'Demario Davis',
#  'DoweAn00': 'Andrew Dowell',
#  'EastNi00': 'Nick Easton',
#  'ElliKa00': 'Kaden Elliss',
#  'FowlBe00': 'Bennie Fowler',
#  'GardCh00': 'Chauncey Gardner-Johnson',
#  'GlasRy00': 'Ryan Glasgow',
#  'GranCa01': 'Carl Granderson',
#  'GrayJ.00': 'J.T. Gray',
#  'GreeEt00': 'Ethan Greenidge',
#  'GrifGa00': 'Garrett Griffin',
#  'HaleGr00': 'Grant Haley',
#  'HansCh02': 'Chase Hansen',
#  'HardJu01': 'Justin Hardee',
#  'HarrDe07': 'Deonte Harris',
#  'HendTr00': 'Trey Hendrickson',
#  'HillJo02': 'Josh Hill',
#  'HillTa00': 'Taysom Hill',
# ...

# %%
from sportsreference.nfl.roster import Player
drew_brees = Player('BreeDr00')
drew_brees.dataframe
# Out:
#         adjusted_net_yards_per_attempt_index  \
# 2001                                     NaN
# 2002                                    96.0
# 2003                                    81.0
# 2004                                   129.0
# 2005                                   106.0
# 2006                                   127.0
# 2007                                   107.0
# 2008                                   122.0
# 2009                                   131.0
# 2010                                   103.0
# 2011                                   132.0
# 2012                                   116.0
# 2013                                   121.0
# 2014                                   109.0
# 2015                                   116.0
# 2016                                   116.0
# 2017                                   121.0
# 2018                                   131.0
# 2019                                   126.0
# 2020                                   117.0
# ...

# %%
for column in drew_brees.dataframe.columns:
    print(column)
# Out:
# adjusted_net_yards_per_attempt_index
# adjusted_net_yards_per_pass_attempt
# adjusted_yards_per_attempt
# adjusted_yards_per_attempt_index
# all_purpose_yards
# approximate_value
# assists_on_tackles
# attempted_passes
# birth_date
# blocked_punts
# catch_percentage
# completed_passes
# completion_percentage_index
# espn_qbr
# extra_point_percentage
# extra_points_attempted
# extra_points_made
# field_goal_percentage
# field_goals_attempted
# field_goals_made
# fifty_plus_yard_field_goal_attempts
# fifty_plus_yard_field_goals_made
# fourth_quarter_comebacks
# fourty_to_fourty_nine_yard_field_goal_attempts
# fourty_to_fourty_nine_yard_field_goals_made
# fumbles
# fumbles_forced
# fumbles_recovered
# fumbles_recovered_for_touchdown
# game_winning_drives
# games
# games_started
# height
# interception_percentage
# interception_percentage_index
# interceptions
# interceptions_returned_for_touchdown
# interceptions_thrown
# kickoff_return_touchdown
# kickoff_return_yards
# ...

# %% [markdown]
# ### Creating Dataset
